# %%
import pandas as pd

# %% [markdown]
# Creating Dataframe

# %%
# using lists

data_sample = [
    [50,60,47],
    [70,73,75],
    [100,400,34],
    [60,5,20]
]
data = pd.DataFrame(data_sample,columns=['Python','C++','Java'])
print(data)
# Out:
#    Python  C++  Java
# 0      50   60    47
# 1      70   73    75
# 2     100  400    34
# 3      60    5    20

# %%
# using dicts
Data_dicts = {
    'col1':['name1','name2','name3','name4','name5','name5'],
    'col2':[100,34,234,55,66,66],
    'col3':[10,3,23,5,66,66],
    'col4':[1002,342,2342,552,66,66],
    'col5':[1002,342,2342,552,66,66],
}
students = pd.DataFrame(Data_dicts)
print(students)
students.set_index('col1',inplace=True)
print(students)
# Out:
#     col1  col2  col3  col4  col5
# 0  name1   100    10  1002  1002
# 1  name2    34     3   342   342
# 2  name3   234    23  2342  2342
# 3  name4    55     5   552   552
# 4  name5    66    66    66    66
# 5  name5    66    66    66    66
#        col2  col3  col4  col5
# col1
# name1   100    10  1002  1002
# name2    34     3   342   342
# name3   234    23  2342  2342
# name4    55     5   552   552
# name5    66    66    66    66
# name5    66    66    66    66

# %%
import pandas as pd

# %%
# using read_CSV
weather = pd.read_csv("./Data/austin_weather.csv")
print(weather)
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
titanic = pd.read_csv("./Data/Titanic Dataset.csv")
print(titanic)
# titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# Dataframe Attributes and methods

# %%
# shape
print(titanic.shape)
print(weather.shape)
# Out:
# (418, 12)
# (1319, 21)

# %%
# dtypes
print(titanic.dtypes)
print()
print(weather.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#
# Date                          object
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# ...

# %%
#  index
print(titanic.index)
print(weather.index)
print(students.index)
# Out:
# RangeIndex(start=0, stop=418, step=1)
# RangeIndex(start=0, stop=1319, step=1)
# Index(['name1', 'name2', 'name3', 'name4', 'name5', 'name6'], dtype='object', name='col1')

# %%
#  columns
print(titanic.columns)
print(weather.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
#  values
print(type(titanic))
print(type(titanic.values))
print(titanic.values)
print()
print(weather.values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# [[892 0 3 ... 7.8292 nan 'Q']
#  [893 1 3 ... 7.0 nan 'S']
#  [894 0 2 ... 9.6875 nan 'Q']
#  ...
#  [1307 0 3 ... 7.25 nan 'S']
#  [1308 0 3 ... 8.05 nan 'S']
#  [1309 0 3 ... 22.3583 nan 'C']]
#
# [['2013-12-21' 74 60 ... '31' '0.46' 'Rain , Thunderstorm']
#  ['2013-12-22' 56 48 ... '25' '0' ' ']
#  ['2013-12-23' 58 45 ... '12' '0' ' ']
#  ...
#  ['2017-07-29' 107 92 ... '17' '0' ' ']
#  ['2017-07-30' 106 93 ... '20' '0' ' ']
#  ['2017-07-31' 99 88 ... '20' '0' ' ']]

# %% [markdown]
# Pandas Datagrame functions

# %%
# head and tail
print(titanic.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(titanic.head(2))
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
print(titanic.tail())
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
print(titanic.tail(2))
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex  Age  \
# 416         1308         0       3       Ware, Mr. Frederick  male  NaN
# 417         1309         0       3  Peter, Master. Michael J  male  NaN
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 416      0      0  359309   8.0500   NaN        S
# 417      1      1    2668  22.3583   NaN        C

# %%
print(titanic.sample())
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 139         1031         0       3  Goodwin, Mr. Charles Frederick  male
#
#       Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 139  40.0      1      6  CA 2144  46.9   NaN        S

# %%
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# None

# %%
print(titanic.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
print(titanic.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print(titanic.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print(titanic.duplicated().sum())
# Out:
# 0
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
print(students.duplicated().sum())
data = students.drop_duplicates()
print(data.duplicated().sum())
# Out:
# 1
# 0

# %%
x = students.rename(columns={'col2':'Python','col3':'C++'},inplace=True)
print(x)
print(students)
# x = students.rename(columns={'col2':'Python','col3':'C++'},inplace=False)
# print(x)
# Out:
# None
#        Python  C++  col4  col5
# col1
# name1     100   10  1002  1002
# name2      34    3   342   342
# name3     234   23  2342  2342
# name4      55    5   552   552
# name5      66   66    66    66
# name5      66   66    66    66

# %%
print(students.sum(axis=0)) # column

print(students.sum(axis=1)) # row
# Out:
# Python     555
# C++        173
# col4      4370
# col5      4370
# dtype: int64
# col1
# name1    2114
# name2     721
# name3    4941
# name4    1164
# name5     264
# name5     264
# dtype: int64

# %%
students.mean(axis=1)
students.mean(axis=0)
# Out:
# Python     92.500000
# C++        28.833333
# col4      728.333333
# col5      728.333333
# dtype: float64

# %%
print(students.var())
# Out:
# Python      5262.300000
# C++          877.366667
# col4      747306.266667
# col5      747306.266667
# dtype: float64

# %%
# standard deviation
print(students.std())
# Out:
# Python     72.541712
# C++        29.620376
# col4      864.468777
# col5      864.468777
# dtype: float64

# %% [markdown]
# selecting cols from dataframe

# %%
titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
titanic['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
titanic[['PassengerId','Name','Pclass']]
# Out:
#      PassengerId                                          Name  Pclass
# 0            892                              Kelly, Mr. James       3
# 1            893              Wilkes, Mrs. James (Ellen Needs)       3
# 2            894                     Myles, Mr. Thomas Francis       2
# 3            895                              Wirz, Mr. Albert       3
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3
# ..           ...                                           ...     ...
# 413         1305                            Spector, Mr. Woolf       3
# 414         1306                  Oliva y Ocana, Dona. Fermina       1
# 415         1307                  Saether, Mr. Simon Sivertsen       3
# 416         1308                           Ware, Mr. Frederick       3
# 417         1309                      Peter, Master. Michael J       3
#
# [418 rows x 3 columns]

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
weather.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
weather[['Date','TempAvgF','Events']]
# Out:
#             Date  TempAvgF               Events
# 0     2013-12-21        60  Rain , Thunderstorm
# 1     2013-12-22        48
# 2     2013-12-23        45
# 3     2013-12-24        46
# 4     2013-12-25        50
# ...          ...       ...                  ...
# 1314  2017-07-27        89
# 1315  2017-07-28        91
# 1316  2017-07-29        92
# 1317  2017-07-30        93
# 1318  2017-07-31        88
#
# [1319 rows x 3 columns]

# %% [markdown]
# iloc - searches using index positions
# loc - searches using index labels

# %%
# accessing single row
titanic.iloc[5]
# Out:
# PassengerId                           897
# Survived                                0
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                  14.0
# SibSp                                   0
# Parch                                   0
# Ticket                               7538
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 5, dtype: object

# %%
# accessing mulltiple row together
titanic.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.iloc[[0,3,5,56,44,33,232]]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 3            895         0       3
# 5            897         0       3
# 56           948         0       3
# 44           936         1       1
# 33           925         1       3
# 232         1124         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                     Kelly, Mr. James    male  34.5      0
# 3                                     Wirz, Mr. Albert    male  27.0      0
# 5                           Svensson, Mr. Johan Cervin    male  14.0      0
# 56                                     Cor, Mr. Bartol    male  35.0      0
# 44    Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)  female  45.0      1
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female   NaN      1
# 232                            Wiklund, Mr. Karl Johan    male  21.0      1
#
#      Parch      Ticket     Fare Cabin Embarked
# ...

# %%
students
# Out:
#        Python  C++  col4  col5
# col1
# name1     100   10  1002  1002
# name2      34    3   342   342
# name3     234   23  2342  2342
# name4      55    5   552   552
# name5      66   66    66    66
# name5      66   66    66    66

# %%
students.loc['name1']
# Out:
# Python     100
# C++         10
# col4      1002
# col5      1002
# Name: name1, dtype: int64

# %%
students.loc[['name1','name2','name5']]
# Out:
#        Python  C++  col4  col5
# col1
# name1     100   10  1002  1002
# name2      34    3   342   342
# name5      66   66    66    66
# name5      66   66    66    66

# %%
students.loc['name1':'name4':2]

# %% [markdown]
# Selecting both row and columns

# %%
titanic.iloc[0:3,0:7] # rows,columns
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp
# 0  34.5      0
# 1  47.0      1
# 2  62.0      0

# %%
titanic.loc[0:9:2,'PassengerId':'Pclass']
# Out:
#    PassengerId  Survived  Pclass
# 0          892         0       3
# 2          894         0       2
# 4          896         1       3
# 6          898         1       3
# 8          900         1       3

# %%
# Create new columns in data frame
titanic['Country'] = 'India'
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 297         1189         0       3
# 134         1026         0       3
# 289         1181         0       3
# 98           990         1       3
# 187         1079         0       3
# 311         1203         0       3
# 362         1254         1       2
# 90           982         1       3
# 13           905         0       2
# 77           969         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 297                                  Samaan, Mr. Hanna    male   NaN      2
# 134                             Dintcheff, Mr. Valtcho    male  43.0      0
# 289                                   Ford, Mr. Arthur    male   NaN      0
# 98                        Braf, Miss. Elin Ester Maria  female  20.0      0
# 187                                 Davies, Mr. Joseph    male  17.0      2
# 311                               Vartanian, Mr. David    male  22.0      0
# ...

# %%
titanic['First Name'] = titanic['Name'].str.split(' ').apply(lambda x:x[0])
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 416         1308         0       3                       Ware, Mr. Frederick
# 336         1228         0       2                de Brito, Mr. Jose Joaquim
# 214         1106         1       3    Andersson, Miss. Ida Augusta Margareta
# 251         1143         0       3  Abrahamsson, Mr. Abraham August Johannes
# 346         1238         0       2                Botsford, Mr. William Hull
# 124         1016         0       3                         Kennedy, Mr. John
# 99           991         0       3              Nancarrow, Mr. William Henry
# 155         1047         0       3                      Duquemin, Mr. Joseph
# 410         1302         1       3                    Naughton, Miss. Hannah
# 313         1205         1       3                       Carr, Miss. Jeannie
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# ...

# %%
x = ["how","are","you"]

y=" ".join(x)
print(y)
# Out:
# how are you

# %%
name = input()
print(" ".join(name.split(" ")[:-1]))
# Out:
# sneha raj

# %% [markdown]
# astype()

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
#  12  Country      418 non-null    object
#  13  First Name   418 non-null    object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 45.8+ KB

# %%
titanic['PassengerId'] = titanic['PassengerId'].astype('int32')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int32
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
#  12  Country      418 non-null    object
#  13  First Name   418 non-null    object
# dtypes: float64(2), int32(1), int64(4), object(7)
# memory usage: 44.2+ KB

# %%
weather.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
print(weather.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %%
weather['Events'] = weather['Events'].astype('category')
titanic['First name'] = titanic['Sex'].astype('category')

# %%
print(weather.info())
print(titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %% [markdown]
# Value_count()

# %%
students
# Out:
#        col2  col3  col4  col5
# col1
# name1   100    10  1002  1002
# name2    34     3   342   342
# name3   234    23  2342  2342
# name4    55     5   552   552
# name5    66    66    66    66
# name5    66    66    66    66

# %%
students.value_counts() # counting no. of rows
# Out:
# col2  col3  col4  col5
# 66    66    66    66      2
# 34    3     342   342     1
# 55    5     552   552     1
# 100   10    1002  1002    1
# 234   23    2342  2342    1
# Name: count, dtype: int64

# %%
# 
students['col2'].value_counts()
# Out:
# col2
# 66     2
# 100    1
# 34     1
# 234    1
# 55     1
# Name: count, dtype: int64

# %%
titanic['Pclass'].unique()
# Out:
# array([3, 2, 1])

# %%
# find how many passenger are there in each line
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
weather['Events'].value_counts()
# Out:
# Events
#                              903
# Rain                         192
# Rain , Thunderstorm          137
# Fog , Rain , Thunderstorm     33
# Fog                           21
# Thunderstorm                  17
# Fog , Rain                    14
# Fog , Thunderstorm             1
# Rain , Snow                    1
# Name: count, dtype: int64

# %%
# count of passenger which are males and age is above 40
((titanic["Age"] >= 40) & (titanic["Sex"]=='male')).value_counts()
# Out:
# False    366
# True      52
# Name: count, dtype: int64

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
((titanic['SibSp']==0)&(titanic['Parch']==0)).value_counts()
# Out:
# True     253
# False    165
# Name: count, dtype: int64

# %%
(((titanic['Sex']=='male')&(titanic['Age']>50))|((titanic['Sex']=='female')&(titanic['Age']>=40))).value_counts()
# Out:
# False    372
# True      46
# Name: count, dtype: int64

# %% [markdown]
# sort_values()

# %%
titanic.sort_values('PassengerId',ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 417         1309         0       3
# 416         1308         0       3
# 415         1307         0       3
# 414         1306         1       1
# 413         1305         0       3
# ..           ...       ...     ...
# 4            896         1       3
# 3            895         0       3
# 2            894         0       2
# 1            893         1       3
# 0            892         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 417                      Peter, Master. Michael J    male   NaN      1      1
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# ...

# %%
titanic.sort_values('PassengerId')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.sort_values(['Pclass','Name'],ascending=[True,False])
# Out:
#      PassengerId  Survived  Pclass  \
# 371         1263         1       1
# 23           915         0       1
# 231         1123         1       1
# 218         1110         1       1
# 407         1299         0       1
# ..           ...       ...     ...
# 8            900         1       3
# 251         1143         0       3
# 57           949         0       3
# 345         1237         1       3
# 392         1284         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 371                     Wilson, Miss. Helen Alice  female  31.0      0      0
# 23                Williams, Mr. Richard Norris II    male  21.0      0      1
# 231                      Willard, Miss. Constance  female  21.0      0      0
# 218  Widener, Mrs. George Dunton (Eleanor Elkins)  female  50.0      1      1
# 407                    Widener, Mr. George Dunton    male  50.0      1      1
# ...

# %% [markdown]
# set_index()

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.set_index('PassengerId',inplace=True)

# %%
titanic
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
titanic.reset_index(inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# marks_series = marks_series.reset_index(inplace=True)

# %%
titanic['Age'] = titanic['Age'].fillna('----')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
