# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./Data/StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.value_counts('race/ethnicity')
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
data.rename(columns={'race/ethnicity':'groups'},inplace=True)

# %%
data.sample(5)
# Out:
#      gender   groups parental level of education         lunch  \
# 827  female  group C            some high school      standard
# 486    male  group D                some college  free/reduced
# 119  female  group C                some college      standard
# 636  female  group B                 high school  free/reduced
# 831  female  group C           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 827                    none          65             69             76
# 486                    none          61             47             56
# 119                    none          55             69             65
# 636               completed          67             80             81
# 831               completed          74             86             89

# %%
print(data['gender'].unique())
print(data['groups'].unique())
print(data['parental level of education'].unique())
print(data['lunch'].unique())
print(data['test preparation course'].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ['standard' 'free/reduced']
# ['none' 'completed']

# %%
groups = data.groupby('groups')

# %%
print(groups)

# %%
type(groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for group,data in groups:
    print(group)
    print(data)
# Out:
# group A
#      gender   groups parental level of education         lunch  \
# 3      male  group A          associate's degree  free/reduced
# 13     male  group A                some college      standard
# 14   female  group A             master's degree      standard
# 25     male  group A             master's degree  free/reduced
# 46   female  group A          associate's degree      standard
# ..      ...      ...                         ...           ...
# 974  female  group A                some college      standard
# 983  female  group A                some college      standard
# 985    male  group A                 high school      standard
# 988  female  group A            some high school  free/reduced
# 994    male  group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
parental = data.groupby('parental level of education')

# %%
for group,data in parental:
    print(group)
    print(data)
# Out:
# associate's degree
#      gender   groups parental level of education         lunch  \
# 35     male  group E          associate's degree      standard
# 44   female  group E          associate's degree  free/reduced
# 51     male  group E          associate's degree  free/reduced
# 56   female  group E          associate's degree      standard
# 83     male  group E          associate's degree      standard
# 107    male  group E          associate's degree      standard
# 149    male  group E          associate's degree  free/reduced
# 190  female  group E          associate's degree      standard
# 216  female  group E          associate's degree  free/reduced
# 246    male  group E          associate's degree      standard
# 286    male  group E          associate's degree      standard
# 297    male  group E          associate's degree      standard
# 332    male  group E          associate's degree      standard
# 349    male  group E          associate's degree      standard
# ...

# %% [markdown]
# # Aggregate function

# %%
groups.sum(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group A        5485           5756           5578
# group B       12056          12797          12464
# group C       20564          22044          21637
# group D       17649          18348          18378
# group E       10335          10224           9997

# %%
groups.mean(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group A   61.629213      64.674157      62.674157
# group B   63.452632      67.352632      65.600000
# group C   64.463950      69.103448      67.827586
# group D   67.362595      70.030534      70.145038
# group E   73.821429      73.028571      71.407143

# %%
groups.median(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group A        61.0           64.0           62.0
# group B        63.0           67.0           67.0
# group C        65.0           71.0           68.0
# group D        69.0           71.0           72.0
# group E        74.5           74.0           72.0

# %%
groups.max(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group A         100            100             97
# group B          97             97             96
# group C          98            100            100
# group D         100            100            100
# group E         100            100            100

# %%
groups.count()
# Out:
#          gender  parental level of education  lunch  test preparation course  \
# groups
# group A      89                           89     89                       89
# group B     190                          190    190                      190
# group C     319                          319    319                      319
# group D     262                          262    262                      262
# group E     140                          140    140                      140
#
#          math score  reading score  writing score
# groups
# group A          89             89             89
# group B         190            190            190
# group C         319            319            319
# group D         262            262            262
# group E         140            140            140

# %%
groups.std(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group A   14.523008      15.543762      15.468278
# group B   15.468191      15.177499      15.625173
# group C   14.852666      13.997033      14.983378
# group D   13.769386      13.895306      14.367707
# group E   15.534259      14.874024      15.113906

# %%
groups.get_group('group A').head()
# Out:
#     gender   groups parental level of education         lunch  \
# 3     male  group A          associate's degree  free/reduced
# 13    male  group A                some college      standard
# 14  female  group A             master's degree      standard
# 25    male  group A             master's degree  free/reduced
# 46  female  group A          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 13               completed          78             72             70
# 14                    none          50             53             58
# 25                    none          73             74             72
# 46               completed          55             65             62

# %%
# Find that group which scored highest total in math

print(groups['math score'].sum().sort_values().tail(1))
# Out:
# groups
# group C    20564
# Name: math score, dtype: int64

# %%
# Find that group which scored average highest avg in wrting 

print(groups['writing score'].mean().sort_values().tail(1))
# Out:
# groups
# group E    71.407143
# Name: writing score, dtype: float64

# %%
print(parental['math score'].max().sort_values().tail(3))
# Out:
# parental level of education
# bachelor's degree     100
# associate's degree    100
# some college          100
# Name: math score, dtype: int64

# %%
parental['math score'].max().sort_values()
# Out:
# parental level of education
# master's degree        94
# some high school       94
# high school            99
# bachelor's degree     100
# associate's degree    100
# some college          100
# Name: math score, dtype: int64

# %%
groups.groups
# Out:
# {'group A': [3, 13, 14, 25, 46, 61, 62, 72, 77, 82, 88, 112, 129, 143, 150, 151, 170, 228, 250, 296, 300, 305, 327, 356, 365, 368, 378, 379, 384, 395, 401, 402, 423, 428, 433, 442, 444, 464, 467, 468, 483, 489, 490, 506, 511, 539, 546, 571, 575, 576, 586, 589, 591, 597, 614, 623, 635, 651, 653, 688, 697, 702, 705, 731, 741, 769, 778, 805, 810, 811, 816, 820, 830, 832, 837, 851, 892, 902, 911, 936, 943, 960, 966, 972, 974, 983, 985, 988, 994], 'group B': [0, 2, 5, 6, 7, 9, 12, 17, 21, 26, 31, 39, 42, 43, 45, 65, 68, 75, 80, 81, 94, 96, 100, 103, 108, 109, 116, 121, 125, 126, 136, 146, 152, 157, 158, 160, 162, 167, 168, 176, 178, 188, 192, 198, 199, 203, 208, 209, 215, 218, 219, 221, 224, 232, 238, 247, 248, 252, 258, 274, 279, 284, 285, 287, 288, 295, 303, 308, 310, 311, 318, 329, 333, 335, 338, 342, 346, 350, 355, 360, 361, 380, 396, 398, 406, 407, 413, 424, 443, 448, 449, 459, 461, 474, 480, 484, 488, 494, 498, 501, ...], 'group C': [1, 4, 10, 15, 16, 18, 19, 23, 27, 28, 40, 41, 47,
# ...

# %%
data.iloc[3]
# Out:
# gender                                     male
# groups                                  group E
# parental level of education    some high school
# lunch                                  standard
# test preparation course               completed
# math score                                   77
# reading score                                76
# writing score                                77
# Name: 289, dtype: object

# %%
groups.ngroups
# Out:
# 5

# %%
groups.size()
# Out:
# groups
# group A     89
# group B    190
# group C    319
# group D    262
# group E    140
# dtype: int64

# %%
groups.indices
# Out:
# {'group A': array([  3,  13,  14,  25,  46,  61,  62,  72,  77,  82,  88, 112, 129,
#         143, 150, 151, 170, 228, 250, 296, 300, 305, 327, 356, 365, 368,
#         378, 379, 384, 395, 401, 402, 423, 428, 433, 442, 444, 464, 467,
#         468, 483, 489, 490, 506, 511, 539, 546, 571, 575, 576, 586, 589,
#         591, 597, 614, 623, 635, 651, 653, 688, 697, 702, 705, 731, 741,
#         769, 778, 805, 810, 811, 816, 820, 830, 832, 837, 851, 892, 902,
#         911, 936, 943, 960, 966, 972, 974, 983, 985, 988, 994]),
#  'group B': array([  0,   2,   5,   6,   7,   9,  12,  17,  21,  26,  31,  39,  42,
#          43,  45,  65,  68,  75,  80,  81,  94,  96, 100, 103, 108, 109,
#         116, 121, 125, 126, 136, 146, 152, 157, 158, 160, 162, 167, 168,
#         176, 178, 188, 192, 198, 199, 203, 208, 209, 215, 218, 219, 221,
#         224, 232, 238, 247, 248, 252, 258, 274, 279, 284, 285, 287, 288,
#         295, 303, 308, 310, 311, 318, 329, 333, 335, 338, 342, 346, 350,
# ...

# %%
# Custom Agreegation

groups.agg({
    'math score':'mean',
    'reading score':'max',
    'writing score':'sum',
})
# Out:
#          math score  reading score  writing score
# groups
# group A   61.629213            100           5578
# group B   63.452632             97          12464
# group C   64.463950            100          21637
# group D   67.362595            100          18378
# group E   73.821429            100           9997

# %%
groups.agg({
    'math score':['mean','min'],
    'reading score':'std',
    'writing score':['sum','max','min'],
})
# Out:
#         math score     reading score writing score
#               mean min           std           sum  max min
# groups
# group A  61.629213  28     15.543762          5578   97  19
# group B  63.452632   8     15.177499         12464   96  15
# group C  64.463950   0     13.997033         21637  100  10
# group D  67.362595  26     13.895306         18378  100  32
# group E  73.821429  30     14.874024          9997  100  22
