# %%
import pandas as pd

# %%
titanic = pd.read_csv('../Pandas/Data/Titanic Dataset.csv')
print(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Display the names of all passengers who paid a fare greater than $100 and were under the age of 30

((titanic['Fare']>100)&(titanic['Age']<30)).value_counts()
# Out:
# False    411
# True       7
# Name: count, dtype: int64

# %%
titanic[(titanic['Fare']>100)&(titanic['Age']<30)]['Name']
# Out:
# 53                            Fortune, Miss. Ethel Flora
# 64                           Ryerson, Master. John Borie
# 156                                    Bird, Miss. Ellen
# 184    Douglas, Mrs. Frederick Charles (Mary Helene B...
# 196                      Spedden, Master. Robert Douglas
# 252                             Clark, Mr. Walter Miller
# 272        Clark, Mrs. Walter Miller (Virginia McDowell)
# Name: Name, dtype: object

# %%
# Find the top 5 oldest passengers. What are their names, ages, and whether they survived?
titanic[['Name','Age','Survived']].sort_values('Age',ascending=False).head(5)
# Out:
#                                                   Name   Age  Survived
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  76.0         1
# 81                                  Straus, Mr. Isidor  67.0         0
# 236                           Warren, Mr. Frank Manley  64.0         0
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  64.0         1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  64.0         1

# %%
# Count how many passengers have a missing value for their cabin number (Cabin).

titanic['Cabin'].isnull().sum()
# Out:
# np.int64(327)

# %%
# Extract and create a new column called 'Title' from the 'Name' column (e.g., Mr., Mrs., Miss, etc.). After creating the column, display the first 5 unique titles. 

titanic['title'] = titanic['Name'].str.split(", ").apply(lambda x:x[0])
print(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
