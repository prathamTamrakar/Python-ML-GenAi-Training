# %%
# string
str = 'pratham'
print(str) # pratham
print(str[0]) # p
print(str[-1]) # m
str = "Let's Learn Python"
print(str[::-3])
print(str[7::4])
print(str[10:])
print(str[::3])
print(str[-3:-10:-5])
print(str[-2:])
# Out:
# pratham
# p
# m
# nt a t
# e h
# n Python
# L'LrPh
# hn
# on

# %%
str = 'pratham'
str.upper() # 'PRATHAM'
str.lower() # 'pratham'
str.capitalize() # 'Pratham'
str.isupper() # False
# Out:
# False

# %%
str = "Hello Everyone"
x = list(str)
print(x)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'E', 'v', 'e', 'r', 'y', 'o', 'n', 'e']

# %%
str = "Hello Everyone Lets's Learn Python"
x = str.split(" ")
print(x)
# Out:
# ['Hello', 'Everyone', "Lets's", 'Learn', 'Python']

# %% [markdown]
# WAP which will  takes a string from the user and print longest string

# %%
str = "Hello Everyone Lets's Learn Python"
# str = eval(input(Hello Everyone Lets's Learn Python))
x = str.split(" ")
print(x)
index = 0
length = 0
n = 0
for i in x:
    print(i,len(i))
    if(length<len(i)):
        length = len(i)
        index = n
    n+=1    

print(x[index],"length is maximum and its length is: ",length)
# Out:
# ['Hello', 'Everyone', "Lets's", 'Learn', 'Python']
# Hello 5
# Everyone 8
# Lets's 6
# Learn 5
# Python 6
# Everyone length is maximum and its length is:  8

# %%
str = "Hello Everyone Lets's Learn Python"
# str = eval(input(Hello Everyone Lets's Learn Python))
x = str.split(" ")
print(x)
temp = ""
for i in x:
    if(len(temp)<len(i)):
        temp=i
print(temp,"length is maximum and its length is: ",len(temp))
# Out:
# ['Hello', 'Everyone', "Lets's", 'Learn', 'Python']
# Everyone length is maximum and its length is:  8

# %%
x = "apple orange apple guava apple banana"
print(x)
y=
print(y) # mango orange mango guava mango banana
# Out:
# apple orange apple guava apple banana
# mango orange mango guava mango banana

# %%
x = 'Hello,Everyone.how,are.you'

x=x.replace(".","#")
x=x.replace(",",".")
x=x.replace("#",",")

    
print(x)
# Out:
# Hello.Everyone,how.are,you

# %% [markdown]
# check the pallindrome

# %%
x = "ptrtp"
if x==x[::-1]:
    print('pallindrome')
else:
    print('not a pallindrome')
# Out:
# pallindrome

# %% [markdown]
# Set
# unique value duplicate values removes
# mutable

# %%
st1 = set()
st2 = {}
print(type(st1))
print(type(st2))
# Out:
# <class 'set'>
# <class 'dict'>

# %%
st = {1,2,3,3,4,5,5,"hello"}
print(st) # {'hello', 1, 2, 3, 4, 5}
# Out:
# {'hello', 1, 2, 3, 4, 5}

# %%
st = {1,3,5}
st.add(7)
# st.add((7,8,9))
st.update([1,2,3,4,5,10,7,8,9],(10,11,12))
print(st)
# Out:
# {1, 2, 3, 4, 5, 7, 8, 9, 10, 11, 12}

# %%
st = {1,3,4,5,6,7,7,5}
st.discard(1)
print(st)
st.remove(5) # throw error
print(st)
emst = st.clear
print(emst)
print(st)
del st
print(st) # Name error
# Out:
# {3, 4, 5, 6, 7}
# {3, 4, 6, 7}
# <built-in method clear of set object at 0x0000023812F22F80>
# {3, 4, 6, 7}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[155], line 10
#       8 print(st)
#       9 del st
# ---> 10 print(st) # Name error
#
# NameError: name 'st' is not defined

# %% [markdown]
# WAp which will take input as string and count unique words

# %%
x = input()
# y = x.split()
# y=set(y)
# print(len(y))

print(len(set(x.split())))
# Out:
# 0

# %%
x = input()
lst1 = x.split()
lst2=[]

for i in lst1:
    if i not in lst2:
        lst2.append(i)
print(lst2)
# Out:
# {'how', 'they', 'you', 'are'}
# ['how', 'are', 'they', 'you']
