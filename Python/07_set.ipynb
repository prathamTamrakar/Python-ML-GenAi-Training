# %%
s = {1,2,3,4,5,6}
s1 = frozenset([1,2,3,4,5,6])
# makes immutable
print(s1)
# Out:
# frozenset({1, 2, 3, 4, 5, 6})

# %%
s1 = {1,2,3,4,5,6}
s2 = {2,3,6,7,5,4,10}
print(s1|s2)
print(s1&s2)
print(s1-s2)
print(s2-s1)
print((s1|s2)-(s1&s2))
print(s1^s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 10}
# {2, 3, 4, 5, 6}
# {1}
# {10, 7}
# {1, 10, 7}
# {1, 7, 10}
