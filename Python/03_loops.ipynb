# %%
i=1
while i<19 :
    print(i,end=" ")
    i+=2
# Out:
# 1 3 5 7 9 11 13 15 17

# %%
i=25
sum=0
while i>=25 and i<=70 :
    if i%2==1:
        sum = sum + i
    i+=1
print(sum)
# Out:
# 1081

# %%
n = int(input("Enter any number"))
i=1
while i<=n:
    if n%i==0:
        print(i,end=" ")
    i+=1
# Out:
# 1 2 3 4 6 12

# %%
n = int(input("Enter any number"))
fact=1
while n>0:
    fact=fact*n
    n-=1
print(fact)
# Out:
# 120

# %%
n = int(input("Enter any number"))
digit=0
while n!=0:
    n = n // 10
    i+=1
print(i)
# Out:
# 4

# %%
n = int(input("Enter any number"))
sum=0
while n!=0:
    num=n%10
    n=n//10
    sum+=num
print(sum)
# Out:
# 15

# %% [markdown]
# number reverse
# pallindrome
# narsisistic number
